# %% [markdown]
# # Neuro-Fit Minor Touchups Notebook
#
# This notebook was added with a small maintenance commit on a feature branch.

# %%
def fitcoin_formula(reps: int, form_score: float, velocity_multiplier: float) -> float:
    return round(max(0, reps) * max(0.0, form_score) * max(0.0, velocity_multiplier), 2)

fitcoin_formula(10, 8.0, 1.2)

# %%
# Quick reminder of the pose-classifier feature shape:
num_landmarks = 33
coords_per_landmark = 3  # x, y, z
num_features = num_landmarks * coords_per_landmark
num_features
